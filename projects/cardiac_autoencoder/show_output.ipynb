# %%
import argparse
import os
import tqdm
import SimpleITK as sitk
import numpy as np
import matplotlib.pyplot as plt

# %%
img3d = sitk.ReadImage('/rds/projects/c/chenhp-dpmodel/2024-miccai-dgm-daum/projects/cardiac_autoencoder/VQImages/output_image_10.nii.gz')
img3d_fl = sitk.Cast(img3d, sitk.sitkFloat32)

image_np = sitk.GetArrayFromImage(img3d_fl)

if image_np.ndim == 3:
    middle_slice = image_np[:,:,image_np.shape[-1] // 2]  # Get the middle slice
    plt.imshow(middle_slice, cmap='gray')
else:
    plt.imshow(image_np, cmap='gray')

plt.title('Real Image')
plt.axis('off')  # Hide axis for better view
plt.show()

# %%
img3d = sitk.ReadImage('/rds/projects/c/chenhp-dpmodel/2024-miccai-dgm-daum/projects/cardiac_autoencoder/VQRecons/output_image_10.nii.gz')
img3d_fl = sitk.Cast(img3d, sitk.sitkFloat32)

image_np = sitk.GetArrayFromImage(img3d_fl)

if image_np.ndim == 3:
    middle_slice = image_np[:,:,image_np.shape[-1] // 2]  # Get the middle slice
    plt.imshow(middle_slice, cmap='gray')
else:
    plt.imshow(image_np, cmap='gray')

plt.title('Real Image')
plt.axis('off')  # Hide axis for better view
plt.show()
